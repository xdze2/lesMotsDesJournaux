# %%
from matplotlib import pyplot as plt
# %matplotlib inline  

import pandas as pd

# %%
import json
import re
import dataset
from datetime import datetime

# %%
# Load DB
db_file = 'database_occurences.db'
db = dataset.connect('sqlite:///%s'%db_file)
occurences = db['occurences']

# %%
def getDate( day ):
    date = datetime.strptime(day, '%d-%m-%Y')
    return date

# %%
# Nombre_tot_mots_par_jour
dates_v = []
nMots_v = []

result = db.query(" SELECT day, COUNT(*) c FROM occurences GROUP BY day ")
for row in result:
    dates_v.append( getDate( row['day'] ) )
    nMots_v.append( row['c'] )
    
nMots_serie = pd.Series( nMots_v, index=dates_v )

# -- Config. start date:
start_date  = getDate(u'16-03-2016')
end_date = datetime.now()

# Plot
nMots_serie.plot(figsize=(12, 4) )
plt.xlim(xmin=start_date)
plt.show()

# %%
from matplotlib.dates import DateFormatter
formatter = DateFormatter('%d/%m')

def plotTimeLine( mot ):
    
    s = seriecount( mot )
    
    plt.figure(figsize=(10,2.5))
    plt.plot( s.index, s , linewidth=2 )
    plt.title(mot)
    plt.axhline(y=s.mean(), color='r', linestyle='--',  linewidth=1.2 )
    plt.axhline(y=s.mean()+s.std(), color='r', linestyle=':')
    
    if s.min() < s.mean()-s.std():
        plt.axhline(y=s.mean()-s.std(), color='r', linestyle=':')
    if s.max() > s.mean()+2*s.std():
        plt.axhline(y=s.mean()+2*s.std(), color='r', linestyle=':')
    if s.max() > s.mean()+3*s.std():
        plt.axhline(y=s.mean()+3*s.std(), color='r', linestyle=':')
        
    plt.axhline(y=s.median(), color='k', linestyle=':')    
    plt.ylim(ymin=0)
    plt.gcf().axes[0].xaxis.set_major_formatter(formatter)
    plt.show()

# %%
plotTimeLine( 'Donald Trump' )
plotTimeLine( 'Trump' )
plotTimeLine( 'Valls' )

# %%
plotTimeLine( u'déchéance' )

# %%
plotTimeLine( u'élection' )
plotTimeLine( u'deux' )
plotTimeLine( u'intelligence artificielle')

# %%
plotTimeLine( u'Rémi Fraisse' )
plotTimeLine( u'vache folle' )
plotTimeLine( u'discours')

# %%
plotTimeLine( u'international' )
plotTimeLine( u'métro' )
plotTimeLine( u'Reda Kriket')
plotTimeLine( u'Molenbeek')
plotTimeLine( u'Bruxelles')

# %%
# -- load --
filename = './data_rss/count_global.json'
data = json.loads(open(filename).read())

print len( data )
# Out:
# 24607

# %%
sorted_nuplet = sorted( data.items(), key=lambda x:len(x[0]), reverse=True )
top_mots = [x[0] for x in sorted_nuplet if x[1]>21]
print ', '.join(  [x[0]+' (%i)'%x[1] for x in sorted_nuplet if x[1]>21] )
# Out:
# la déchéance de nationalité (29), révision constitutionnelle (31), Premier ministre (49), la loi El Khomri (26), réseaux sociaux (35), investissements (25), antiterroriste (27), Salah Abdeslam (128), Dilma Rousseff (30), fonctionnaires (38), internationale (36), investissement (43), professionnels (25), manifestations (50), présidentielle (82), participation (30), international (58), établissement (23), manifestation (36), développement (35), investisseurs (26), Ile-de-France (24), responsables (27), négociations (36), Barack Obama (44), Centrafrique (23), Donald Trump (63), Manuel Valls (57), rémunération (32), consommation (28), républicains (47), interdiction (23), organisation (42), Johan Cruyff (31), mobilisation (59), gouvernement (193), journalistes (36), informations (42), concurrence (22), terroristes (72), stratégique (23), application (25), financement (29), nationalité (27), américaines (36), Royaume-Uni (39), information (34), agriculture (26), arrestation (56), plate-forme (23), 13 novembre (89), journaliste (45), internautes (27), djihadistes (49), candidature (33), spécialiste (26), association (47), extradition (23), républicain (25), responsable (33), Reda Kriket (39), britannique (63), entreprises (123), secrétaire (38), économique (63), présidente (30), comprendre (29), terroriste (87), françaises (45), production (36), commission (42), conférence (26), électrique (22), automobile (26), présidence (24), nomination (28), dispositif (26), Strasbourg (22), pédophilie (33), enquêteurs (29), corruption (40), financière (22), fédération (31), États-Unis (32), américains (40), historique (41), télévision (22), conditions (42), judiciaire (51), politiques (50), Washington (49), Volkswagen (48), Etats-Unis (99), djihadiste (53), population (29), terrorisme (103), république (50), européenne (108), angleterre (22), entreprise (67), participer (31), pourraient (22), dirigeants (25), opposition (48), révolution (26), américaine (84), croissance (69), libération (23), nombreuses (28), soupçonné (31), situation (37), française (119), déchéance (39), notamment (91), policiers (43), assurance (23), fondateur (29), numérique (29), devraient (22), actualité (32), résultats (40), opération (77), direction (28), intérieur (34), questions (54), difficile (26), certaines (26), prochaine (23), désormais (64), lendemain (31), appellent (22), El Khomri (45), plusieurs (142), kamikazes (27), politique (159), transport (33), stratégie (22), principal (28), explosion (39), violences (40), syndicats (62), critiques (23), activités (25), quotidien (31), troisième (46), quatrième (22), mouvement (43), identifié (25), argentine (31), américain (109), septembre (30), interview (25), nouvelles (95), rencontre (29), milliards (135), nationale (70), printemps (24), Bruxelles (495), militaire (36), ministère (52), islamique (33), personnes (146), étrangers (25), populaire (26), opposants (25), champions (39), programme (42), policière (24), quartiers (35), compagnie (31), recherche (35), attentats (537), européens (26), nucléaire (54), directeur (74), Allemagne (58), autorités (72), coalition (23), étudiants (37), sanctions (26), également (44), aéroports (22), Marseille (32), ministres (45), dernières (31), candidats (55), passagers (31), procureur (27), président (263), primaires (34), assemblée (46), Molenbeek (75), formation (25), Cazeneuve (24), procédure (33), polémique (53), familles (29), Facebook (23), décembre (24), Abdeslam (47), pompiers (28), contrôle (43), allemand (35), festival (36), parisien (38), attentat (146), suspects (24), milliard (30), deuxième (63), histoire (74), victimes (141), kamikaze (23), services (42), occasion (55), candidat (90), milliers (28), football (75), François (123), problème (26), personne (27), gendarme (25), campagne (67), question (42), condamné (70), sécurité (128), possible (50), présence (22), primaire (98), pression (26), beaucoup (41), New York (31), attaques (78), critique (25), vendredi (158 ...

# %%
def plotBoxplot( mot ):
    s = seriecount(mot)

    plt.show()

# %%
mots = ['France', 'deux', 'Donald Trump', 'attentats', 'belge', 'la loi El Khomri', 'Washington']

# %%
motsseries = [seriecount(m) for m in mots]

bxplt_dataframe = pd.concat(motsseries, join='inner', axis = 1)
bxplt_dataframe.columns = mots

plt.figure(figsize=(10,3))
bxplt_dataframe.boxplot(return_type ='axes')
plt.show()

# %%
# global stat

# %%
import numpy as np

# %%
seuil = 20
top_mots = [x[0] for x in data.items() if x[1]>seuil]
print len( top_mots )
print ', '.join( top_mots[:14] ), ' ...'
# Out:
# 980
# Euro, Valls, familles, chine, radicalisation, peur, concurrence, fin, terroristes, toute, service, affaire, accusé, Rio  ...

# %%
glob_stat = {}

for mot in top_mots:
    s = seriecount(mot)

    glob_stat[mot] = {'mean':s.mean(), 'std':s.std(), 'max':s.max(), 'median':s.median(), 'skew':s.skew()} 
    #glob_stat[mot]['count'] = sum( data_by_day[mot].values() )
    #glob_stat[mot]['maxmin'] = np.max(values_v) - np.min(values_v)
    glob_stat[mot]['max_mean_std'] = ( s.max()-s.mean() ) / s.std()
    glob_stat[mot]['max_mean_mean'] = ( s.max()-s.mean() ) / s.mean()
    #glob_stat[mot]['fisher'] = s.kurtosis( fisher=True)
    glob_stat[mot]['mean_std'] =  s.mean() - s.std()
    glob_stat[mot]['min'] =  s.min()
    
mesures_name = glob_stat.values()[0].keys()
mesures = {}
for mesure in mesures_name:
    mesures[mesure] = [glob_stat[mot][mesure] for mot in top_mots ]

# %%
m = top_mots[  np.array( mesures['skew'] ).argmax() ]
print np.array( mesures['skew'] ).min()

plotTimeLine( m)

s = seriecount(mot)
# Out:
# -1.30791457918

# %%
def printTop20( mesure, reverse=True ):
    t = [ (mot, glob_stat[mot][mesure]) for mot in top_mots ]
    s = sorted( t, key= lambda x:x[1], reverse=reverse )
    print ', '.join( [ x[0]+' (%.2f)'%x[1] for x in s[:100] ]), ' ...'

# %%
printTop20('min')
# Out:
# France (2.93), ans (2.80), attentats (1.68), mars (1.67), président (1.10), groupe (0.95), quatre (0.89), pays (0.89), nouveau (0.76), deux (0.76), dernier (0.72), français (0.67), face (0.67), trois (0.67), monde (0.64), homme (0.64), grand (0.63), hollande (0.55), attentat (0.51), première (0.51), Europe (0.51), ministre (0.51), premier (0.51), près (0.51), victimes (0.47), moins (0.45), malgré (0.43), ancien (0.39), justice (0.38), mois (0.38), sous (0.38), plusieurs (0.38), jour (0.38), annoncé (0.37), fin (0.37), toujours (0.36), travail (0.36), police (0.36), projet (0.36), centre (0.36), point (0.36), alors (0.36), jours (0.36), état (0.36), notamment (0.36), américain (0.36), sécurité (0.35), terroriste (0.32), affaire (0.32), devrait (0.32), Paris (0.32), temps (0.32), gauche (0.27), Syrie (0.27), politique (0.26), Bruxelles (0.26), nouvelles (0.26), lieu (0.26), vie (0.26), comment (0.25), année (0.25), début (0.24), matin (0.24), heures (0.24), procès (0.24), soir (0.23), autorités (0.22), semaine (0.22), hommage (0.22), reste (0.22), chez (0.22), région (0.22), chef (0.14), condamné (0.13), pouvoir (0.13), dimanche (0.13), cause (0.13), troisième (0.12), pourquoi (0.12), lundi (0.12), belgique (0.12), équipe (0.12), estime (0.12), NBA (0.12), retour (0.11), course (0.11), la déchéance de nationalité (0.00), révision constitutionnelle (0.00), Premier ministre (0.00), la loi El Khomri (0.00), réseaux sociaux (0.00), investissements (0.00), antiterroriste (0.00), Salah Abdeslam (0.00), Dilma Rousseff (0.00), fonctionnaires (0.00), internationale (0.00), investissement (0.00), professionnels (0.00), manifestations (0.00)  ...

